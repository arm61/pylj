# %%
# %matplotlib notebook
import warnings
warnings.filterwarnings('ignore')
from pylj import md, sample, force

# %%
number_of_particles = 100
temperature = 1
number_of_steps = 10000

# %%
particles, system = md.initialise(number_of_particles, temperature)
sample_system = sample.Scattering(system)
system.time = 0
for i in range(0, number_of_steps):
    particles, system = force.compute_forces(particles, system)
    particles, system = md.update_positions(particles, system)
    system.time += system.timestep_length
    if system.step % 10 == 0:
        sample_system.update(particles, system)
# Out:
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e996a03d605a> in <module>()
#       7     system.time += system.timestep_length
#       8     if system.step % 10 == 0:
# ----> 9         sample_system.update(particles, system)
#
# ~/Dropbox/work/teaching/pylj/pylj/sample.py in update(self, particles, system)
#      76
#      77
# ---> 78         self.fig.canvas.draw()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     180             backend_agg.RendererAgg.lock.release()
#     181             # Swap the frames
# --> 182             self.manager.refresh_all()
#     183
#     184     def draw_idle(self):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in refresh_all(self)
#     479     def refresh_all(self):
#     480         if self.web_sockets:
# --> 481             diff = self.canvas.get_diff_image()
#     482             for s in self.web_sockets:
#     483                 s.send_binary(diff)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in get_diff_image(self)
#     231             buff = _png.write_png(
#     232                 output.view(dtype=np.uint8).reshape(output.shape + (4,)),
# --> 233                 None, compression=6, filter=_png.PNG_FILTER_NONE)
#     234
#     235             # Swap the renderer frames
#
# KeyboardInterrupt:
