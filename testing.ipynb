# %%
from pylj import md

# %%
md.run(324, 1, 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1549b1516ed0> in <module>()
# ----> 1 md.run(324, 1, 1000)
#
# ~/Dropbox/work/teaching/pylj/pylj/md.py in run(number_of_particles, kinetic_energy, number_steps)
#     196         particles, time, temp, system = time_step(particles, system, time)
#     197         if system.step % 10 == 0:
# --> 198             show(particles, system)
#     199         system.step0 = reset_histogram(system)
#
# ~/Dropbox/work/teaching/pylj/pylj/md.py in show(particles, system)
#     183         gr = plot_gr(system, gs)
#     184         plot_scat(gr, gs)
# --> 185     display.display(plt.gcf())
#     186     display.clear_output(wait=True)
#     187     plt.close()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...
