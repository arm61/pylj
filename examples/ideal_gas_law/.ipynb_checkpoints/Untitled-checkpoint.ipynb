# %%
import warnings
from pylj import md, sample
from pylj import forcefields as ff
import numpy as np
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
def md_simulation(number_of_particles, temperature, box_length, number_of_steps, sample_frequency):
    # Creates the visualisation environment
    # %matplotlib notebook
    # Initialise the system
    system = md.initialise(number_of_particles, temperature, box_length, 'square', 
                           constants=[1.69e-15, 3.66e10, 1.02e-77], forcefield=ff.buckingham)
    # This sets the sampling class
    sample_system = sample.Energy(system)
    # Start at time 0
    system.time = 0
    # Begin the molecular dynamics loop
    for i in range(0, number_of_steps):
        # Run the equations of motion integrator algorithm, this 
        # includes the force calculation
        system.integrate(md.velocity_verlet)
        # Sample the thermodynamic and structural parameters of the system
        system.md_sample()
        # Allow the system to interact with a heat bath
        system.heat_bath(temperature)
        # Iterate the time
        system.time += system.timestep_length
        system.step += 1
        # At a given frequency sample the positions and plot the RDF
        if system.step % sample_frequency == 0:
            sample_system.update(system)
    return system

# %%
md_simulation(50, 273.15, 100, 5000, 25)
# Out:
# MD 1 <function buckingham at 0x7f6a372d0268>
# <img src="data:image/png;base64,..." width="799.3333333333334">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4a267d068698> in <module>()
# ----> 1 md_simulation(50, 273.15, 100, 5000, 25)
#
# <ipython-input-1-3574f267d61d> in md_simulation(number_of_particles, temperature, box_length, number_of_steps, sample_frequency)
#      21         # Run the equations of motion integrator algorithm, this
#      22         # includes the force calculation
# ---> 23         system.integrate(md.velocity_verlet)
#      24         # Sample the thermodynamic and structural parameters of the system
#      25         system.md_sample()
#
# /home/adam/anaconda3/lib/python3.6/site-packages/pylj-1.1.16-py3.6-linux-x86_64.egg/pylj/util.py in integrate(self, method)
#     163                                                                             self.cut_off,
#     164                                                                             self.constants,
# --> 165                                                                             self.forcefield)
#     166
#     167     def md_sample(self):
#
# /home/adam/anaconda3/lib/python3.6/site-packages/pylj-1.1.16-py3.6-linux-x86_64.egg/pylj/md.py in velocity_verlet(particles, timestep_length, box_length, cut_off, constants, forcefield)
#      93     xacceleration_store = list(particles['xacceleration'])
#      94     yacceleration_store = list(particles['yacceleration'])
# ---> 95     particles, distances, forces, energies = heavy.compute_force(particles, box_length, cut_off, constants, forcefield)
#      96     [particles['xvelocity'], particles['yvelocity']] = update_velocities(
#      97         [particles['xvelocity'], particles['yvelocity']],
#
# /home/adam/anaconda3/lib/python3.6/site-packages/pylj-1.1.16-py3.6-linux-x86_64.egg/pylj/pairwise.py in compute_force(particles, box_length, cut_off, constants, forcefield, mass)
#      56     energies[np.where(distances > cut_off)] = 0.
#      57     particles = update_accelerations(particles, forces, mass_kg, dx, dy,
# ---> 58                                      distances)
#      59     return particles, distances, forces, energies
#      60
#
# /home/adam/anaconda3/lib/python3.6/site-packages/pylj-1.1.16-py3.6-linux-x86_64.egg/pylj/pairwise.py in update_accelerations(particles, f, m, dx, dy, dr)
#      99     for i in range(0, particles.size-1):
#     100         for j in range(i + 1, particles.size):
# --> 101             particles['xacceleration'][i] += second_law(f[k], m, dx[k], dr[k])
#     102             particles['yacceleration'][i] += second_law(f[k], m, dy[k], dr[k])
#     103             particles['xacceleration'][j] -= second_law(f[k], m, dx[k], dr[k])
#
# /home/adam/anaconda3/lib/python3.6/site-packages/pylj-1.1.16-py3.6-linux-x86_64.egg/pylj/pairwise.py in second_law(f, m, d1, d2)
#     125         Acceleration of the particle in a given dimension.
#     126     """
# --> 127     return (f * d1 / d2) / m
#     128
#     129
#
# KeyboardInterrupt:
